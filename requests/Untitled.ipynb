# %%
import requests
import webbrowser
import bs4
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-ce6506318dc9> in <module>
#       1 import requests
#       2 import webbrowser
# ----> 3 import bs4
#
# ModuleNotFoundError: No module named 'bs4'

# %%
# Searh for results in Google
search = 'Mozart'
search_url = 'https://www.google.com/search?q=Mozart'


res = requests.get(search_url + search)
res.status_code
# Out:
# 200

# %%
res_soup =
# Out:
# '<!doctype html><html lang="es-419"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>MozartMozart - Buscar con Google</title><script nonce="DQm9_yG_STxnki2v0Z_ALg">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){window.google=window.google||{};var a=window.performance&&window.performance.timing&&"navigationStart"in window.performance.timing,b=google.stvsc&&google.stvsc.ns,c=a?b||window.performance.timing.navigationStart:void 0,d=google.stvsc&&google.stvsc.rs
# ...
